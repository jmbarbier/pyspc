# %% [markdown]
# |Instructions|Bibliothèque|Rôle|Chapitre sur le site
# |-------------------------|----------------------------------------|-----------------------------------|------------------------------------|
# |\caractère spécial|...|Insére un caractère spécial|[Affectation des variables et impression des résultats](http://www.grpp.demo.dumezil.devel.space/05-bases/02-variables_input_print.html)
# |\n|...|Retour à la ligne (chaîne de caractères)|[Affectation des variables et impression des résultats](http://www.grpp.demo.dumezil.devel.space/05-bases/02-variables_input_print.html)
# |\t|...|Insère une tabulation|[Affectation des variables et impression des résultats](http://www.grpp.demo.dumezil.devel.space/05-bases/02-variables_input_print.html)
# |#|...| Indique un commentaire| [Structure d'un programme](http://www.grpp.demo.dumezil.devel.space/05-bases/01-structure-programme.html#l%E2%80%99importance-du-commentaire)
# |%|...|	Opérateur modulo|	[Opérations basiques](http://www.grpp.demo.dumezil.devel.space/05-bases/04-operations_basiques.html)
# |**|...|Opérateur puissance|[Opérations basiques](http://www.grpp.demo.dumezil.devel.space/05-bases/04-operations_basiques.html)
# |==|...|Test d'égalité|[Les boucles](http://www.grpp.demo.dumezil.devel.space/05-bases/06-boucles.html)
# |abs|...|Calcule la valeur absolue|[Opérations basiques](http://www.grpp.demo.dumezil.devel.space/05-bases/04-operations_basiques.html)
# |and|....|Opérateur logique ET|[Opérations basiques](http://www.grpp.demo.dumezil.devel.space/05-bases/04-operations_basiques.html)
# |animation|matplotlib.pyplot|	Simule le défilement d’une courbe|	[Comment animer un graphique?](http://www.grpp.demo.dumezil.devel.space/05-bases/12-animation.html)
# |append|...|	Ajoute une valeur à une liste|	[Les listes](http://www.grpp.demo.dumezil.devel.space/05-bases/08-listes.html)
# |arange|numpy|	Crée un tableau|[Les listes](http://www.grpp.demo.dumezil.devel.space/05-bases/08-listes.html)
# |array|numpy|	Crée un tableau|	[Les listes](http://www.grpp.demo.dumezil.devel.space/05-bases/08-listes.html)
# |arrow|matplotlib.pyplot|	Trace un vecteur|	[Comment créer un graphique-2?](http://www.grpp.demo.dumezil.devel.space/05-bases/10-graphiques_partie_2.html)
# |axis|matplotlib.pyplot|Gère les bornes des axes|[Comment créer un graphique-1?](http://www.grpp.demo.dumezil.devel.space/05-bases/10-graphiques_partie_1.html)
# |break|...|Interrompt une boucle|[Les boucles](http://www.grpp.demo.dumezil.devel.space/05-bases/06-boucles.html)
# |choice|random|	Renvoie au hasard un élément d’une liste|[Les listes](http://www.grpp.demo.dumezil.devel.space/05-bases/08-listes.html)
# |continue|...|Saute une étape dans une boucle  | [Les boucles](http://www.grpp.demo.dumezil.devel.space/05-bases/06-boucles.html)
# |def|...| 	Définit une fonction|	[Les fonctions](http://www.grpp.demo.dumezil.devel.space/05-bases/05-bases/07-fonctions.html)
# |elif|...|Test "sinon si"|[Les tests](http://www.grpp.demo.dumezil.devel.space/05-bases/05-tests.html)
# |else|...|	Test « sinon »|	[Les tests](http://www.grpp.demo.dumezil.devel.space/05-bases/05-tests.html)
# |end|...| Saut à la ligne dans les affichages|[Affectation des variables et impression des résultats](http://www.grpp.demo.dumezil.devel.space/05-bases/02-variables_input_print.html)
# |figure|matplotlib.pyplot|	Crée une fenêtre graphique|	[Comment créer un graphique-1?](http://www.grpp.demo.dumezil.devel.space/05-bases/10-graphiques_partie_1.html)
# |float|...|	Convertit vers un réel|	[Affectation des variables et impression des résultats](http://www.grpp.demo.dumezil.devel.space/05-bases/02-variables_input_print.html)
# |for...in|...|	Boucle "de .. à" |	[Les boucles](http://www.grpp.demo.dumezil.devel.space/05-bases/06-boucles.html)
# |format|...|Formate les valeurs affichées|[Affectation des variables et impression des résultats](http://www.grpp.demo.dumezil.devel.space/05-bases/02-variables_input_print.html)
# |global|...|Définit une variable comme étant globale|[Les fonctions](http://www.grpp.demo.dumezil.devel.space/05-bases/05-bases/07-fonctions.html)
# |grid|matplotlib.pyplot|	Affiche une grille sur le graphique|	[Comment créer un graphique-1?](http://www.grpp.demo.dumezil.devel.space/05-bases/10-graphiques_partie_1.html)
# |if|...|	Test « si »|[Les tests](http://www.grpp.demo.dumezil.devel.space/05-bases/05-tests.html)
# |import|...|	Importe des bibliothèques|	[Structure d'un programme](http://www.grpp.demo.dumezil.devel.space/05-bases/01-structure-programme.html)
# |in|...|Vérifie si une valeur est présente | [Les tests](http://www.grpp.demo.dumezil.devel.space/05-bases/05-tests.html)
# |input|...|	Lit ce qui est tapé sur le clavier|[Affectation des variables et impression des résultats](http://www.grpp.demo.dumezil.devel.space/05-bases/02-variables_input_print.html)
# |insert|...|	Insère un élément dans une liste|	[Les listes](http://www.grpp.demo.dumezil.devel.space/05-bases/08-listes.html)
# |int|...|	Convertit vers un entier|	[Affectation des variables et impression des résultats](http://www.grpp.demo.dumezil.devel.space/05-bases/02-variables_input_print.html)
# |join|...|	Concatène les éléments d’une liste séparés par un séparateur|[Les listes](http://www.grpp.demo.dumezil.devel.space/05-bases/08-listes.html)
# |legend |matplotlib.pyplot|	Affiche les étiquettes d'un graphique|	[Comment créer un graphique-1?](http://www.grpp.demo.dumezil.devel.space/05-bases/10-graphiques_partie_1.html)
# |len|...|	Renvoie la taille d’une liste|[Les listes](http://www.grpp.demo.dumezil.devel.space/05-bases/08-listes.html)
# |linspace |numpy|	Crée un tableau|	[Les listes](http://www.grpp.demo.dumezil.devel.space/05-bases/08-listes.html)
# |list  |...|	Convertit une chaîne de caractères en liste de caractères| [Les listes](http://www.grpp.demo.dumezil.devel.space/05-bases/08-listes.html)
# |min|...|	Renvoie le plus petit élément d’une liste|	[Les listes](http://www.grpp.demo.dumezil.devel.space/05-bases/08-listes.html)
# |max|...|	Renvoie le plus grand élément d’une liste|	[Les listes](http://www.grpp.demo.dumezil.devel.space/05-bases/08-listes.html)
# |MultipleLocator|matplotlib.ticker|Gradue les axes|[Comment créer un graphique-1?](http://www.grpp.demo.dumezil.devel.space/05-bases/10-graphiques_partie_1.html)
# |not in|...|Vérifie qu'une valeur ne soit pas présente|[Les tests](http://www.grpp.demo.dumezil.devel.space/05-bases/05-tests.html)
# |open|...|Ouvre un fichier|[Comment importer des données numériques ?](http://www.grpp.demo.dumezil.devel.space/05-bases/09-fichiers-csv.html)
# |or|...|	Opérateur logique OU|	[Opérations basiques](http://www.grpp.demo.dumezil.devel.space/05-bases/04-operations_basiques.html)
# |plot |matplotlib.pyplot|	Crée un graphique|	[Comment créer un graphique-1?](http://www.grpp.demo.dumezil.devel.space/05-bases/10-graphiques_partie_1.html)
# |polyfit|numpy|	Modélise une courbe|	[Comment modéliser une courbe?](http://www.grpp.demo.dumezil.devel.space/05-bases/11-modelisation.html)
# |pop	|...|Supprime un élément d’une liste|	[Les listes](http://www.grpp.demo.dumezil.devel.space/05-bases/08-listes.html)
# |print|...|	Affiche à l’écran|	[Affectation des variables et impression des résultats](http://www.grpp.demo.dumezil.devel.space/05-bases/02-variables_input_print.html)
# |range |...|Définit un intervalle|[Les boucles](http://www.grpp.demo.dumezil.devel.space/05-bases/06-boucles.html)
# |reader|...|Lit un fichier|[Comment importer des données numériques ?](http://www.grpp.demo.dumezil.devel.space/05-bases/09-fichiers-csv.html)
# |remove|...|	Supprime un élément d’une liste|	[Les listes](http://www.grpp.demo.dumezil.devel.space/05-bases/08-listes.html)
# |return|...|	Renvoi d’une valeur par la fonction| 	[Les fonctions](http://www.grpp.demo.dumezil.devel.space/05-bases/05-bases/07-fonctions.html)
# |round|...|	Arrondit une valeur|	[Affectation des variables et impression des résultats](http://www.grpp.demo.dumezil.devel.space/05-bases/02-variables_input_print.html)
# |sample|random|	Renvoie au hasard un ou plusieurs éléments d’une liste|	[Les listes](http://www.grpp.demo.dumezil.devel.space/05-bases/08-listes.html)
# |sep|...|Insère un séparateur entre plusieurs affichages|[Affectation des variables et impression des résultats](http://www.grpp.demo.dumezil.devel.space/05-bases/02-variables_input_print.html)
# |show |matplotlib.pyplot|Affiche le graphique|		[Comment créer un graphique-1?](http://www.grpp.demo.dumezil.devel.space/05-bases/10-graphiques_partie_1.html)
# |sort|...|	Trie une liste|	[Les listes](http://www.grpp.demo.dumezil.devel.space/05-bases/08-listes.html)
# |sorted	|...|Trie une liste|	[Les listes](http://www.grpp.demo.dumezil.devel.space/05-bases/08-listes.html)
# |sqrt|...|Calcule la racine carrée|[Opérations basiques](http://www.grpp.demo.dumezil.devel.space/05-bases/04-operations_basiques.html)
# |subplot |matplotlib.pyplot|	Divise la fenêtre graphique en plusieurs emplacements|	[Comment créer un graphique-2?](http://www.grpp.demo.dumezil.devel.space/05-bases/10-graphiques_partie_2.html)
# |subplots_adjust|matplotlib.pyplot.gcf()|Définit la position d'un graphique dans un emplacement|	[Comment créer un graphique-2?](http://www.grpp.demo.dumezil.devel.space/05-bases/10-graphiques_partie_2.html)
# |text|matplotlib.pyplot| Affiche un texte sur le graphique|[Comment créer un graphique-1?](http://www.grpp.demo.dumezil.devel.space/05-bases/10-graphiques_partie_1.html)
# |title|...|	Nomme un graphique|	[Comment créer un graphique-1?](http://www.grpp.demo.dumezil.devel.space/05-bases/10-graphiques_partie_1.html)
# |type|...|Indique le type d'une variable|[Affectation des variables et impression des résultats](http://www.grpp.demo.dumezil.devel.space/05-bases/02-variables_input_print.html)
# |while|...|	Boucle « tant que »	|	[Les boucles](http://www.grpp.demo.dumezil.devel.space/05-bases/06-boucles.html)
# |xlabel (ou ylabel)|matplotlib.pyplot|	Légende les axes|	[Comment créer un graphique-1?](http://www.grpp.demo.dumezil.devel.space/05-bases/10-graphiques_partie_1.html)
# |xlim ( ou (ylim) |matplotlib.pyplot|	Définit les bornes sur les axes|	[Comment créer un graphique-1?](http://www.grpp.demo.dumezil.devel.space/05-bases/10-graphiques_partie_1.html)
